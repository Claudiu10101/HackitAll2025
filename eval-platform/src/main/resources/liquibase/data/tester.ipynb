# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("flights.csv")

# %%
diff_columns = [x for x in df.columns if "diff" in x and x != "arrival_diff"]

# %%
big_planes = ["b2017ed7-66c7-4498-b647-500ea1ef03d6","020941c7-3b40-4654-8b78-c755f48571c6"]

# %%
df["special"] = (df["sched_aircraft_type_id"] != df["act_aircraft_type_id"]).astype('int16')

df["upsize"] =((df["special"] == 1) & (~df["sched_aircraft_type_id"].isin(big_planes)) & (df["act_aircraft_type_id"].isin(big_planes))).astype("int16")

# %%
df["upsize"].describe()
# Out:
# count    7287.000000
# mean        0.042953
# std         0.202766
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: upsize, dtype: float64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df.select_dtypes(include=numerics)

# %%
df["economy_diff"].hist(bins=100)
# Out:
# <Axes: >

# %%
flight = df[(df["origin_airport_id"] == "381fada9-f9a0-4ee4-a994-228b88e53d35") & (df["destination_airport_id"] == "2f9cdc45-4fe2-4295-849a-56775b65cfe6")]

# %%
df["scheduled_timestamp"].hist(bins=720)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df["scheduled_timestamp"].hist(bins=720).max()
#
# AttributeError: 'Axes' object has no attribute 'max'
