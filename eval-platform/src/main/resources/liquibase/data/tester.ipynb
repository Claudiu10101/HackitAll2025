# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("flights.csv")

# %%
diff_columns = [x for x in df.columns if "diff" in x and x != "arrival_diff"]

# %%
big_planes = ["b2017ed7-66c7-4498-b647-500ea1ef03d6","020941c7-3b40-4654-8b78-c755f48571c6"]

# %%
df["special"] = (df["sched_aircraft_type_id"] != df["act_aircraft_type_id"]).astype('int16')

df["upsize"] =((df["special"] == 1) & (~df["sched_aircraft_type_id"].isin(big_planes)) & (df["act_aircraft_type_id"].isin(big_planes))).astype("int16")

# %%
df["upsize"].describe()
# Out:
# count    7287.000000
# mean        0.042953
# std         0.202766
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: upsize, dtype: float64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df.select_dtypes(include=numerics)

# %%
newdf.corr()
# Out:
#                                     scheduled_depart_day  \
# scheduled_depart_day                            1.000000
# scheduled_depart_hour                          -0.012328
# scheduled_arrival_day                           0.999007
# scheduled_arrival_hour                         -0.006590
# scheduled_timestamp                             0.999499
# scheduled_arrival                               0.999466
# distance                                        0.000387
# actual_distance                                -0.000021
# distance_diff                                   0.002004
# actual_arival_day                               0.998893
# actual_arrival_hour                            -0.005912
# actual_timestamp                                0.999456
# arrival_diff                                   -0.004250
# planned_first_passengers                        0.012825
# actual_first_passengers                         0.010380
# first_diff                                     -0.012500
# planned_business_passengers                     0.010633
# actual_business_passengers                      0.009990
# bussiness_diff                                 -0.012845
# planned_premium_economy_passengers             -0.010748
# actual_premium_economy_passengers              -0.007321
# premium_diff                                    0.017087
# planned_economy_passengers                      0.004326
# actual_economy_passengers                      -0.002377
# economy_diff                                    0.026043
# special                                         0.001322
# upsize                                         -0.015235
#
#                                     scheduled_depart_hour  \
# scheduled_depart_day                            -0.012328
# scheduled_depart_hour                            1.000000
# scheduled_arrival_day                            0.014207
# scheduled_arrival_hour                           0.152574
# scheduled_timestamp                              0.019319
# scheduled_arrival                                0.019516
# distance                                         0.022941
# actual_distance                                  0.023034
# distance_diff                                    0.006001
# actual_arival_day                                0.017230
# actual_arrival_hour                              0.063793
# actual_timestamp                                 0.019464
# arrival_diff                                    -0.010858
# planned_first_passengers                        -0.019114
# actual_first_passengers                         -0.019955
# first_diff                                      -0.008447
# planned_business_passengers                      0.004286
# actual_business_passengers                       0.007023
# bussiness_diff                                   0.013186
# planned_premium_economy_passengers              -0.016085
# actual_premium_economy_passengers               -0.014820
# premium_diff                                     0.007200
# planned_economy_passengers                       0.004425
# actual_economy_passengers                       -0.000105
# economy_diff                                     0.015042
# special                                         -0.002078
# upsize                                          -0.005932
#
#                                     scheduled_arrival_day  \
# scheduled_depart_day                             0.999007
# scheduled_depart_hour                            0.014207
# scheduled_arrival_day                            1.000000
# scheduled_arrival_hour                          -0.037184
# scheduled_timestamp                              0.999346
# scheduled_arrival                                0.999397
# distance                                         0.011312
# actual_distance                                  0.010897
# distance_diff                                    0.001898
# actual_arival_day                                0.999813
# actual_arrival_hour                             -0.034358
# actual_timestamp                                 0.999387
# arrival_diff                                    -0.004401
# planned_first_passengers                         0.012082
# actual_first_passengers                          0.009528
# first_diff                                      -0.013044
# planned_business_passengers                      0.010649
# actual_business_passengers                       0.010025
# bussiness_diff                                  -0.012755
# planned_premium_economy_passengers              -0.011173
# actual_premium_economy_passengers               -0.007856
# premium_diff                                     0.016504
# planned_economy_passengers                       0.004281
# actual_economy_passengers                       -0.002671
# economy_diff                                     0.026288
# special                                          0.001452
# upsize                                          -0.015006
#
#                                     scheduled_arrival_hour  \
# scheduled_depart_day                             -0.006590
# scheduled_depart_hour                             0.152574
# scheduled_arrival_day                            -0.037184
# scheduled_arrival_hour                            1.000000
# scheduled_timestamp                              -0.001761
# scheduled_arrival                                -0.002477
# distance                                         -0.086217
# actual_distance                                  -0.086370
# distance_diff                                     0.005898
# actual_arival_day                                -0.032389
# actual_arrival_hour                               0.859162
# actual_timestamp                                 -0.002501
# arrival_diff                                     -0.004959
# planned_first_passengers                          0.003380
# actual_first_passengers                           0.006408
# first_diff                                        0.010134
# planned_business_passengers                       0.004324
# actual_business_passengers                        0.006400
# bussiness_diff                                    0.010498
# planned_premium_economy_passengers               -0.001604
# actual_premium_economy_passengers                 0.001998
# premium_diff                                      0.019503
# planned_economy_passengers                        0.003648
# actual_economy_passengers                         0.005763
# economy_diff                                      0.010302
# special                                          -0.002564
# upsize                                           -0.007626
#
#                                     scheduled_timestamp  scheduled_arrival  \
# scheduled_depart_day                           0.999499           0.999466
# scheduled_depart_hour                          0.019319           0.019516
# scheduled_arrival_day                          0.999346           0.999397
# scheduled_arrival_hour                        -0.001761          -0.002477
# scheduled_timestamp                            1.000000           0.999973
# scheduled_arrival                              0.999973           1.000000
# distance                                       0.001113           0.008325
# actual_distance                                0.000708           0.007905
# distance_diff                                  0.002194           0.002105
# actual_arival_day                              0.999327           0.999377
# actual_arrival_hour                           -0.003893          -0.004542
# actual_timestamp                               0.999961           0.999988
# arrival_diff                                  -0.004593          -0.004577
# planned_first_passengers                       0.012219           0.012208
# actual_first_passengers                        0.009747           0.009757
# first_diff                                    -0.012765          -0.012701
# planned_business_passengers                    0.010767           0.010807
# actual_business_passengers                     0.010211           0.010254
# bussiness_diff                                -0.012426          -0.012399
# planned_premium_economy_passengers            -0.011256          -0.011237
# actual_premium_economy_passengers             -0.007789          -0.007792
# premium_diff                                   0.017313           0.017193
# planned_economy_passengers                     0.004465           0.004410
# actual_economy_passengers                     -0.002380          -0.002473
# economy_diff                                   0.026517           0.026664
# special                                        0.001256           0.001364
# upsize                                        -0.015421          -0.015281
#
#                                     distance  actual_distance  distance_diff  \
# scheduled_depart_day                0.000387        -0.000021       0.002004
# scheduled_depart_hour               0.022941         0.023034       0.006001
# scheduled_arrival_day               0.011312         0.010897       0.001898
# scheduled_arrival_hour             -0.086217        -0.086370       0.005898
# scheduled_timestamp                 0.001113         0.000708       0.002194
# scheduled_arrival                   0.008325         0.007905       0.002105
# distance                            1.000000         0.997863      -0.012930
# actual_distance                     0.997863         1.000000      -0.071710
# distance_diff                      -0.012930        -0.071710       1.000000
# actual_arival_day                   0.010916         0.010749      -0.002531
# actual_arrival_hour                -0.074164        -0.075130       0.025865
# actual_timestamp                    0.008343         0.008142      -0.001632
# arrival_diff                        0.003659         0.049134      -0.773935
# planned_first_passengers           -0.000160        -0.000955       0.020466
# actual_first_passengers             0.002009         0.001203       0.019720
# first_diff                          0.006860         0.007068      -0.008054
# planned_business_passengers         0.004730         0.004731       0.004078
# actual_business_passengers          0.004830         0.004958       0.001057
# bussiness_diff                      0.000984         0.002046      -0.020112
# planned_premium_economy_passengers  0.005184         0.005995      -0.008884
# actual_premium_economy_passengers   0.002950         0.003937      -0.010261
# premium_diff                       -0.012505        -0.012318       0.004254
# planned_economy_passengers         -0.008415        -0.008683       0.010060
# actual_economy_passengers          -0.013740        -0.013915       0.007482
# economy_diff                        0.022670         0.021789       0.018909
# special                             0.016115         0.016390       0.003548
# upsize                              0.017592         0.017695       0.000992
#
#                                     actual_arival_day  ...  \
# scheduled_depart_day                         0.998893  ...
# scheduled_depart_hour                        0.017230  ...
# scheduled_arrival_day                        0.999813  ...
# scheduled_arrival_hour                      -0.032389  ...
# scheduled_timestamp                          0.999327  ...
# scheduled_arrival                            0.999377  ...
# distance                                     0.010916  ...
# actual_distance                              0.010749  ...
# distance_diff                               -0.002531  ...
# actual_arival_day                            1.000000  ...
# actual_arrival_hour                         -0.039505  ...
# actual_timestamp                             0.999395  ...
# arrival_diff                                 0.001533  ...
# planned_first_passengers                     0.011896  ...
# actual_first_passengers                      0.009343  ...
# first_diff                                  -0.013011  ...
# planned_business_passengers                  0.010760  ...
# actual_business_passengers                   0.010153  ...
# bussiness_diff                              -0.012758  ...
# planned_premium_economy_passengers          -0.011264  ...
# actual_premium_economy_passengers           -0.007894  ...
# premium_diff                                 0.016699  ...
# planned_economy_passengers                   0.004027  ...
# actual_economy_passengers                   -0.002923  ...
# economy_diff                                 0.026281  ...
# special                                      0.001335  ...
# upsize                                      -0.015030  ...
#
#                                     actual_business_passengers  \
# scheduled_depart_day                                  0.009990
# scheduled_depart_hour                                 0.007023
# scheduled_arrival_day                                 0.010025
# scheduled_arrival_hour                                0.006400
# scheduled_timestamp                                   0.010211
# scheduled_arrival                                     0.010254
# distance                                              0.004830
# actual_distance                                       0.004958
# distance_diff                                         0.001057
# actual_arival_day                                     0.010153
# actual_arrival_hour                                   0.004038
# actual_timestamp                                      0.010301
# arrival_diff                                          0.009607
# planned_first_passengers                              0.230263
# actual_first_passengers                               0.238989
# first_diff                                            0.008839
# planned_business_passengers                           0.987726
# actual_business_passengers                            1.000000
# bussiness_diff                                        0.017204
# planned_premium_economy_passengers                    0.095638
# actual_premium_economy_passengers                     0.099178
# premium_diff                                          0.014884
# planned_economy_passengers                            0.216272
# actual_economy_passengers                             0.221080
# economy_diff                                         -0.009526
# special                                              -0.056395
# upsize                                               -0.086318
#
#                                     bussiness_diff  \
# scheduled_depart_day                     -0.012845
# scheduled_depart_hour                     0.013186
# scheduled_arrival_day                    -0.012755
# scheduled_arrival_hour                    0.010498
# scheduled_timestamp                      -0.012426
# scheduled_arrival                        -0.012399
# distance                                  0.000984
# actual_distance                           0.002046
# distance_diff                            -0.020112
# actual_arival_day                        -0.012758
# actual_arrival_hour                       0.013684
# actual_timestamp                         -0.012291
# arrival_diff                              0.022359
# planned_first_passengers                 -0.071123
# actual_first_passengers                   0.039615
# first_diff                                0.454193
# planned_business_passengers              -0.134319
# actual_business_passengers                0.017204
# bussiness_diff                            1.000000
# planned_premium_economy_passengers       -0.022119
# actual_premium_economy_passengers         0.003081
# premium_diff                              0.076952
# planned_economy_passengers               -0.035090
# actual_economy_passengers                 0.022970
# economy_diff                             -0.166887
# special                                  -0.335671
# upsize                                    0.027634
#
#                                     planned_premium_economy_passengers  \
# scheduled_depart_day                                         -0.010748
# scheduled_depart_hour                                        -0.016085
# scheduled_arrival_day                                        -0.011173
# scheduled_arrival_hour                                       -0.001604
# scheduled_timestamp                                          -0.011256
# scheduled_arrival                                            -0.011237
# distance                                                      0.005184
# actual_distance                                               0.005995
# distance_diff                                                -0.008884
# actual_arival_day                                            -0.011264
# actual_arrival_hour                                           0.002847
# actual_timestamp                                             -0.011173
# arrival_diff                                                  0.013179
# planned_first_passengers                                      0.120027
# actual_first_passengers                                       0.118916
# first_diff                                                   -0.017430
# planned_business_passengers                                   0.097341
# actual_business_passengers                                    0.095638
# bussiness_diff                                               -0.022119
# planned_premium_economy_passengers                            1.000000
# actual_premium_economy_passengers                             0.981314
# premium_diff                                                 -0.062995
# planned_economy_passengers                                    0.137628
# actual_economy_passengers                                     0.135522
# economy_diff                                                  0.006277
# special                                                      -0.009241
# upsize                                                       -0.066413
#
#                                     actual_premium_economy_passengers  \
# scheduled_depart_day                                        -0.007321
# scheduled_depart_hour                                       -0.014820
# scheduled_arrival_day                                       -0.007856
# scheduled_arrival_hour                                       0.001998
# scheduled_timestamp                                         -0.007789
# scheduled_arrival                                           -0.007792
# distance                                                     0.002950
# actual_distance                                              0.003937
# distance_diff                                               -0.010261
# actual_arival_day                                           -0.007894
# actual_arrival_hour                                          0.005061
# actual_timestamp                                            -0.007724
# arrival_diff                                                 0.014006
# planned_first_passengers                                     0.118502
# actual_first_passengers                                      0.123190
# first_diff                                                   0.007599
# planned_business_passengers                                  0.097099
# actual_business_passengers                                   0.099178
# bussiness_diff                                               0.003081
# planned_premium_economy_passengers                           0.981314
# actual_premium_economy_passengers                            1.000000
# premium_diff                                                 0.111121
# planned_economy_passengers                                   0.136615
# actual_economy_passengers                                    0.138769
# economy_diff                                                -0.006121
# special                                                     -0.031190
# upsize                                                      -0.061161
#
#                                     premium_diff  planned_economy_passengers  \
# scheduled_depart_day                    0.017087                    0.004326
# scheduled_depart_hour                   0.007200                    0.004425
# scheduled_arrival_day                   0.016504                    0.004281
# scheduled_arrival_hour                  0.019503                    0.003648
# scheduled_timestamp                     0.017313                    0.004465
# scheduled_arrival                       0.017193                    0.004410
# distance                               -0.012505                   -0.008415
# actual_distance                        -0.012318                   -0.008683
# distance_diff                           0.004254                    0.010060
# actual_arival_day                       0.016699                    0.004027
# actual_arrival_hour                     0.012310                    0.009639
# actual_timestamp                        0.017140                    0.004365
# arrival_diff                           -0.010984                   -0.009386
# planned_first_passengers               -0.002761                    0.276557
# actual_first_passengers                 0.016966                    0.271711
# first_diff                              0.081555                   -0.050285
# planned_business_passengers             0.003108                    0.219536
# actual_business_passengers              0.014884                    0.216272
# bussiness_diff                          0.076952                   -0.035090
# planned_premium_economy_passengers     -0.062995                    0.137628
# actual_premium_economy_passengers       0.111121                    0.136615
# premium_diff                            1.000000                    0.001947
# planned_economy_passengers              0.001947                    1.000000
# actual_economy_passengers               0.015812                    0.972049
# economy_diff                           -0.039149                    0.156802
# special                                -0.065201                    0.006799
# upsize                                  0.020115                   -0.082704
#
#                                     actual_economy_passengers  economy_diff  \
# scheduled_depart_day                                -0.002377      0.026043
# scheduled_depart_hour                               -0.000105      0.015042
# scheduled_arrival_day                               -0.002671      0.026288
# scheduled_arrival_hour                               0.005763      0.010302
# scheduled_timestamp                                 -0.002380      0.026517
# scheduled_arrival                                   -0.002473      0.026664
# distance                                            -0.013740      0.022670
# actual_distance                                     -0.013915      0.021789
# distance_diff                                        0.007482      0.018909
# actual_arival_day                                   -0.002923      0.026281
# actual_arrival_hour                                  0.011925      0.008850
# actual_timestamp                                    -0.002511      0.026610
# arrival_diff                                        -0.007861     -0.011322
# planned_first_passengers                             0.272230      0.030107
# actual_first_passengers                              0.284254     -0.019724
# first_diff                                           0.018782     -0.205391
# planned_business_passengers                          0.214921      0.017616
# actual_business_passengers                           0.221080     -0.009526
# bussiness_diff                                       0.022970     -0.166887
# planned_premium_economy_passengers                   0.135522      0.006277
# actual_premium_economy_passengers                    0.138769     -0.006121
# premium_diff                                         0.015812     -0.039149
# planned_economy_passengers                           0.972049      0.156802
# actual_economy_passengers                            1.000000     -0.043691
# economy_diff                                        -0.043691      1.000000
# special                                             -0.050342      0.161366
# upsize                                              -0.077499     -0.024907
#
#                                      special    upsize
# scheduled_depart_day                0.001322 -0.015235
# scheduled_depart_hour              -0.002078 -0.005932
# scheduled_arrival_day               0.001452 -0.015006
# scheduled_arrival_hour             -0.002564 -0.007626
# scheduled_timestamp                 0.001256 -0.015421
# scheduled_arrival                   0.001364 -0.015281
# distance                            0.016115  0.017592
# actual_distance                     0.016390  0.017695
# distance_diff                       0.003548  0.000992
# actual_arival_day                   0.001335 -0.015030
# actual_arrival_hour                -0.000574 -0.007313
# actual_timestamp                    0.001316 -0.015296
# arrival_diff                       -0.009910 -0.002995
# planned_first_passengers            0.012538 -0.125455
# actual_first_passengers            -0.102304 -0.120650
# first_diff                         -0.455161  0.033194
# planned_business_passengers        -0.003280 -0.088995
# actual_business_passengers         -0.056395 -0.086318
# bussiness_diff                     -0.335671  0.027634
# planned_premium_economy_passengers -0.009241 -0.066413
# actual_premium_economy_passengers  -0.031190 -0.061161
# premium_diff                       -0.065201  0.020115
# planned_economy_passengers          0.006799 -0.082704
# actual_economy_passengers          -0.050342 -0.077499
# economy_diff                        0.161366 -0.024907
# special                             1.000000  0.544523
# upsize                              0.544523  1.000000
#
# [27 rows x 27 columns]
