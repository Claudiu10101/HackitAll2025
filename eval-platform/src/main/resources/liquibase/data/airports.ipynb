# %%
import pandas as pd

df = pd.read_csv("airports_with_stocks.csv",sep=";")

# %%
df[df["id"] != "381fada9-f9a0-4ee4-a994-228b88e53d35"]["capacity_fc"].hist()
# Out:
# <Axes: >

# %%
df[df["id"] != "381fada9-f9a0-4ee4-a994-228b88e53d35"]["capacity_fc"].describe()
# Out:
# count    160.00000
# mean     420.67500
# std       85.22966
# min      232.00000
# 25%      353.00000
# 50%      416.00000
# 75%      474.75000
# max      622.00000
# Name: capacity_fc, dtype: float64
